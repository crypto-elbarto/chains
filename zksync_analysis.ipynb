# %%
# !pip install etherscan-python
import http.client
import requests
import pandas as pd
import json
from pandas.io.json import json_normalize
import networkx as nx
from etherscan import Etherscan
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
from google.cloud import bigquery
project_id = 'secure-paratext-345813'
client = bigquery.Client(project=project_id)
# Out:
# WARNING:google.auth._default:No project ID could be determined. Consider running `gcloud config set project` or setting the GOOGLE_CLOUD_PROJECT environment variable

# %%
import http.client
import requests
import pandas as pd
import json
from pandas.io.json import json_normalize
import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/My Drive/Colab Notebooks
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
newdf = pd.read_csv('bq-results-20220527-164741-1653670075827.csv')

# %%
newdf.head()
# Out:
#                                    to_address  \
# 0  0x42e4f53b09250bbbff141b4c7efdff2ad9873ed0
# 1  0x80c67432656d59144ceff962e8faf8926599bcf8
# 2  0x80c67432656d59144ceff962e8faf8926599bcf8
# 3  0x3265ce8629d108a1781e87c7a86e5c43b626368f
# 4  0x2b2a44d107ec260147bfb6a854d10e46b5133b8d
#
#                                  from_address          block_timestamp  \
# 0  0x73f8fc2e74302eb2efda125a326655acf0dc2d1b  2022-05-27 16:40:10 UTC
# 1  0xb285f5dfe4371e3b729890079434a305497cb178  2022-05-27 16:35:34 UTC
# 2  0x8482e81bbb802275247bf4cdab9bc67020231860  2022-05-27 16:38:24 UTC
# 3  0x80c67432656d59144ceff962e8faf8926599bcf8  2022-05-27 16:41:41 UTC
# 4  0xcc9557f04633d82fb6a1741dcec96986cd8689ae  2022-05-27 16:32:24 UTC
#
#         f0_
# 0  0.018043
# 1  0.097700
# 2  0.021300
# 3  0.183125
# 4  2.997839

# %%
newdf.shape
# Out:
# (771151, 4)

# %%
graph = nx.from_pandas_edgelist(newdf,source='to_address',target='from_address',edge_attr='f0_', create_using=nx.DiGraph())

# %%
print('Number of edges',len(graph.edges()))
print('Number of nodes',len(graph.nodes()))
# Out:
# Number of edges 401046
# Number of nodes 113837

# %%
deg_cent = nx.degree_centrality(graph)
deg_cent = sorted(deg_cent.items(), key=lambda x: x[1], reverse=True)

# %%
deg_cent
# Out:
# [('0xabea9132b05a70803a4e85094fd0e1800777fbef', 0.33362908043149797),
#  ('0x80c67432656d59144ceff962e8faf8926599bcf8', 0.2555869847851295),
#  ('0x4dbd4fc535ac27206064b68ffcf827b0a60bab3f', 0.10047788045960857),
#  ('0xc098b2a3aa256d2140208c3de6543aaef5cd3a94', 0.060464176534663905),
#  ('0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48', 0.0517674549351699),
#  ('0xea36bc6697c78c1c8ed9cdeaee6c80994f0cde18', 0.04590814856460171),
#  ('0x7f268357a8c2552623316e2562d90e642bb538e5', 0.04329034751748129),
#  ('0x68b3465833fb72a70ecdf485e0e4c7bd8665fc45', 0.03819529849959591),
#  ('0x737901bea3eeb88459df9ef1be8ff3ae1b42a2ba', 0.035182191925225766),
#  ('0xcc9557f04633d82fb6a1741dcec96986cd8689ae', 0.03454091851435399),
#  ('0x283af0b28c62c092c9727f1ee09c02ca627eb7f5', 0.033530693278049126),
#  ('0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2', 0.030658139780034437),
#  ('0xdac17f958d2ee523a2206206994597c13d831ec7', 0.026344917249376296),
# ...
